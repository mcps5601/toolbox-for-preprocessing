# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

# %%
files = os.listdir("JPEGImages/")
xmls = os.listdir("Annotations/")

# %%
len(files)
len(files)
# Out:
# 334

# %%
x_train, x_test, y_train, y_test = train_test_split(files, xmls, test_size=0.1, random_state=1)

# %%
len(x_train)
# Out:
# 300

# %%
len(x_test)
# Out:
# 34

# %%
trainval = []
for i in x_train:
    print(os.path.splitext(i)[0])
    trainval.append(os.path.splitext(i)[0])
# Out:
# BloodImage_00111
# BloodImage_00357
# BloodImage_00174
# BloodImage_00271
# BloodImage_00290
# BloodImage_00082
# BloodImage_00264
# BloodImage_00260
# BloodImage_00032
# BloodImage_00056
# BloodImage_00161
# BloodImage_00196
# BloodImage_00317
# BloodImage_00180
# BloodImage_00247
# BloodImage_00338
# BloodImage_00256
# BloodImage_00307
# BloodImage_00117
# BloodImage_00349
# BloodImage_00020
# BloodImage_00241
# BloodImage_00023
# BloodImage_00387
# BloodImage_00365
# BloodImage_00159
# BloodImage_00030
# BloodImage_00288
# BloodImage_00124
# BloodImage_00033
# BloodImage_00379
# BloodImage_00248
# BloodImage_00293
# BloodImage_00372
# BloodImage_00123
# BloodImage_00139
# BloodImage_00205
# BloodImage_00281
# BloodImage_00067
# BloodImage_00109
# BloodImage_00193
# BloodImage_00231
# BloodImage_00076
# BloodImage_00337
# BloodImage_00364
# BloodImage_00347
# BloodImage_00028
# BloodImage_00310
# BloodImage_00087
# BloodImage_00044
# BloodImage_00178
# BloodImage_00311
# ...

# %%
test = []
for i in x_test:
    print(os.path.splitext(i)[0])
    test.append(os.path.splitext(i)[0])
# Out:
# BloodImage_00144
# BloodImage_00154
# BloodImage_00049
# BloodImage_00254
# BloodImage_00163
# BloodImage_00278
# BloodImage_00360
# BloodImage_00211
# BloodImage_00009
# BloodImage_00289
# BloodImage_00240
# BloodImage_00005
# BloodImage_00336
# BloodImage_00370
# BloodImage_00309
# BloodImage_00265
# BloodImage_00132
# BloodImage_00095
# BloodImage_00206
# BloodImage_00068
# BloodImage_00236
# BloodImage_00108
# BloodImage_00324
# BloodImage_00058
# BloodImage_00031
# BloodImage_00043
# BloodImage_00182
# BloodImage_00255
# BloodImage_00113
# BloodImage_00298
# BloodImage_00355
# BloodImage_00390
# BloodImage_00342
# BloodImage_00261

# %%
with open('ImageSets/Main/trainval.txt', 'w') as f:
    for item in trainval:
        f.write("%s\n" % item)

# %%
with open('ImageSets/Main/test.txt', 'w') as f:
    for item in trainval:
        f.write("%s\n" % item)
